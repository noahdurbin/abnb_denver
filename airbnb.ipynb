# %% [markdown]
# # Denver Airbnb analysis

# %% [markdown]
# ## import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## import csv using pandas

# %%
df = pd.read_csv('Documents/repos/abnb_denver/listings.csv')

# %%
df
# Out:
#                       id                                      listing_url  \
# 0                    177                 https://www.airbnb.com/rooms/177
# 1                    360                 https://www.airbnb.com/rooms/360
# 2                    364                 https://www.airbnb.com/rooms/364
# 3                    590                 https://www.airbnb.com/rooms/590
# 4                    592                 https://www.airbnb.com/rooms/592
# ...                  ...                                              ...
# 5831  652554037677323304  https://www.airbnb.com/rooms/652554037677323304
# 5832  682714263312033156  https://www.airbnb.com/rooms/682714263312033156
# 5833  602186064397709177  https://www.airbnb.com/rooms/602186064397709177
# 5834            39258605            https://www.airbnb.com/rooms/39258605
# 5835            49092343            https://www.airbnb.com/rooms/49092343
#
#            scrape_id last_scraped           source  \
# ...

# %%
df.shape
# Out:
# (5836, 75)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5836 entries, 0 to 5835
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            5836 non-null   int64
#  1   listing_url                                   5836 non-null   object
#  2   scrape_id                                     5836 non-null   int64
#  3   last_scraped                                  5836 non-null   object
#  4   source                                        5836 non-null   object
#  5   name                                          5836 non-null   object
#  6   description                                   5808 non-null   object
#  7   neighborhood_overview                         4181 non-null   object
#  8   picture_url                                   5836 non-null   object
# ...

# %%
df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  5.836000e+03  5.836000e+03  5.836000e+03          5836.000000
# mean   1.711627e+17  2.022093e+13  1.410124e+08           205.001028
# std    2.834350e+17  1.261827e+00  1.441636e+08           832.744763
# min    1.770000e+02  2.022093e+13  5.890000e+02             1.000000
# 25%    3.196043e+07  2.022093e+13  2.446358e+07             1.000000
# 50%    4.875254e+07  2.022093e+13  8.856686e+07             2.000000
# 75%    5.588694e+17  2.022093e+13  2.243812e+08             7.000000
# max    7.232954e+17  2.022093e+13  4.802227e+08          4129.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                5836.000000                           0.0  5836.000000
# mean                  246.904215                           NaN    39.739690
# std                   982.887994                           NaN     0.037060
# ...

# %% [markdown]
# ## Revealed all present columns

# %%
pd.set_option('display.max_columns', 75)

# %% [markdown]
# ## change price column from a string to an integer

# %%
df['price_new'] = df['price'].str.replace('[\$\,]','', regex=True)
df['price_new'] = pd.to_numeric(df['price_new'])
df['price_new']
# Out:
# 0        79.0
# 1       133.0
# 2       179.0
# 3        72.0
# 4        54.0
#         ...
# 5831     75.0
# 5832     63.0
# 5833    119.0
# 5834     77.0
# 5835     81.0
# Name: price_new, Length: 5836, dtype: float64

# %%
df.neighbourhood_cleansed.unique()
# Out:
# array(['Virginia Village', 'Highland', 'Five Points', 'North Park Hill',
#        'Baker', 'North Capitol Hill', 'West Highland', 'Capitol Hill',
#        'South Park Hill', 'CBD', 'Union Station', 'Washington Park West',
#        'City Park West', 'Clayton', 'City Park', 'Stapleton',
#        'Platt Park', 'Lowry Field', 'Goldsmith', 'University Park',
#        'Congress Park', 'Berkeley', 'Sunnyside', 'Lincoln Park', 'Cole',
#        'Speer', 'Cheesman Park', 'West Colfax', 'Sloan Lake',
#        'Washington Park', 'University', 'Montclair', 'Hilltop',
#        'Country Club', 'Villa Park', 'Cory - Merrill', 'Athmar Park',
#        'Windsor', 'Gateway - Green Valley Ranch', 'Indian Creek',
#        'Rosedale', 'Whittier', 'Fort Logan', 'Skyland', 'Hale',
#        'Cherry Creek', 'Regis', 'Hampden', 'College View - South Platte',
#        'Overland', 'Hampden South', 'Westwood', 'Marston',
#        'Southmoor Park', 'Mar Lee', 'Chaffee Park',
# ...
